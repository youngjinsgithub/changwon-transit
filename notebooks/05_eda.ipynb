# %% [markdown]
# # 05. EDA (탐색적 분석)
#
# **Step 6에서 작성.** 가설 없이 다양하게 탐색. 분석마다 그래프 + 한 줄 인사이트 + 후속 질문 기록.
#
# ## 탐색 항목
# - 기초 통계 (정류장/노선 수, 일 평균 승하차)
# - 시간 패턴 (피크 시간대, 요일별, 새벽·심야)
# - 공간 패턴 (상하위 정류장, 시군구별, 정류장 밀도)
# - 노선 패턴 (등급별 이용량, 노선 길이 vs 이용량)
# - 이상치 (승차만 많은 정류장, 결측 패턴)
# - 관계 (이용량 vs 인근 정류장 수)
