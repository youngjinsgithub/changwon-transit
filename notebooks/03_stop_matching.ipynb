# %% [markdown]
# # 03. 정류장 매칭
#
# STCIS / 창원BIS / TAGO 정류장 ID 통합 매칭. **Step 3에서 작성.**
#
# - 좌표 기반: 30m 이내 동일 판정
# - 이름 기반 보조: fuzzywuzzy 유사도 80+
# - A/B 정류장(상하행) 분리
# - 매칭 실패는 data/processed/unmatched_stops.csv 로 저장
