# %% [markdown]
# # 01. 데이터 수집
#
# STCIS / 창원 BIS / TAGO / 국토부 정류장 위치 CSV 수집 노트북. **Step 2에서 작성.**
#
# - STCIS CSV 다운로드 + 인코딩 자동 감지
# - 창원 BIS API: 정류장·노선 조회 (응답 캐싱)
# - TAGO API: 도시코드 38010 (창원) 노선·정류장
# - 국토부 정류장 위치 CSV 로딩
