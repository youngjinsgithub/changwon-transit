# %% [markdown]
# # 06. 공간 분석 (PostGIS)
#
# **Step 7에서 작성.**
#
# - 정류장 반경 500m 인구 커버리지
# - 행정동별 정류장 수·이용량 집계
# - 정류장 클러스터링 (DBSCAN/K-means)
# - 노선 총 길이 (ST_MakeLine + ST_Length)
# - 환승 가능 정류장 (도보 5분 = 400m)
# - 대중교통 사각지대 시각화
